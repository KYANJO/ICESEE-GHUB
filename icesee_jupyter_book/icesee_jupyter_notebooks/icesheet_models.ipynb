# %% [markdown]
# # ICE-SHEET MODELING

# %%
import sys
from pathlib import Path

# current folder = icesee_jupyter_notebooks
repo_root = Path.cwd().resolve().parents[1]  # this gives ICESEE-GHUB

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from icesee_jupyter_book.ui.icesee_gateway_ui import build_icesee_ui
# from icesee_jupyter_book.ui.icesee_gateway import build_icesee_ui
build_icesee_ui()
