# %%
#%load_ext autoreload
#%autoreload 2

# %% [markdown]
# # Tutorial: ISSM Coupling
#
# This notebook runs the ISSM example using ICESEE's data assimilation driver.

# %%
import os, sys
import platform
import numpy as np
from pathlib import Path

from IPython.display import HTML

# %%
# Setup and preprocessing:

# Current path
Path = os.path.realpath(".")
#print ('Path: %s\n' %Path)

# Parent path
Parentpath = os.path.dirname(Path)
#print ('Parentpath: %s\n' %Parentpath)

# Add to PYTHONPATH
sys.path.append(Parentpath)

# Tool path
Toolpath = os.path.dirname(Parentpath)
#print ('Toolpath: %s\n' %Toolpath)

from utils.configuration import VERBOSE

if VERBOSE:
    
    print ("Operating System Platform: " + platform.system(), platform.release())
    print ("\n")

    print ("os.environ['PATH']: ", os.environ['PATH'])
    print ("sys.path: ", sys.path)
    print ("\n")

# %%
#https://api.jquery.com/ready/
HTML('''
<script>
    function scroll_to_top() {
        Jupyter.notebook.scroll_to_top();
    } 
    $( window ).on( "load", scroll_to_top() );
</script>
''')
# Out:
# <script>
#     function scroll_to_top() {
#         Jupyter.notebook.scroll_to_top();
#     }
#     $( window ).on( "load", scroll_to_top() );
# </script>

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
print ('\nDirectory tree of\n%s:\n' %Toolpath)
from utils.Tree import Tree
results_tree = Tree(Toolpath)
# results_tree.print_tree()
# Out:
# Directory tree of
# /Users/bkyanjo3/da_project/ICESEE-GHUB:

# %%
from _bootstrap._bootstrap import enable_icesee
enable_icesee()
# Out:
# [ICESEE bootstrap] external path enabled: /Users/bkyanjo3/da_project/ICESEE-GHUB/external
# [ICESEE bootstrap] ICESEE loaded from: /Users/bkyanjo3/da_project/ICESEE-GHUB/external/ICESEE/__init__.py
# PosixPath('/Users/bkyanjo3/da_project/ICESEE-GHUB/external')

# %%
# --- call the lorenz96 data assimilation example ---
# go to external/ICESEE
# os.system('cd ../../external/ICESEE/applications/lorenz_model/examples/lorenz96')
import os
os.system('python3 -m ICESEE.applications.issm_model.examples.ISMIP_Choi.run_da_issm')
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/bkyanjo3/da_project/ICESEE-GHUB/external/ICESEE/applications/issm_model/examples/ISMIP_Choi/run_da_issm.py", line 18, in <module>
#     from ICESEE.config._utility_imports import params, kwargs, modeling_params, enkf_params, physical_params,UtilsFunctions
#   File "/Users/bkyanjo3/da_project/ICESEE-GHUB/external/ICESEE/config/_utility_imports.py", line 137, in <module>
#     raise FileNotFoundError(f"Parameter file '{parameters_file}' not found. Please ensure the file exists.")
# FileNotFoundError: Parameter file 'params.yaml' not found. Please ensure the file exists.
# 256

# %%
# call the icesee plotinting notebook
