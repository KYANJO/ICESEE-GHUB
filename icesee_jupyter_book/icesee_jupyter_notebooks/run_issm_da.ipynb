# %%
#%load_ext autoreload
#%autoreload 2

# %% [markdown]
# # Tutorial: ISSM Coupling
#
# This notebook runs the ISSM example using ICESEE's data assimilation driver.

# %%
import os, sys
import platform
import numpy as np
from pathlib import Path

from IPython.display import HTML

# %%
# Setup and preprocessing:

# Current path
Path = os.path.realpath(".")
#print ('Path: %s\n' %Path)

# Parent path
Parentpath = os.path.dirname(Path)
#print ('Parentpath: %s\n' %Parentpath)

# Add to PYTHONPATH
sys.path.append(Parentpath)

# Tool path
Toolpath = os.path.dirname(Parentpath)
#print ('Toolpath: %s\n' %Toolpath)

from utils.configuration import VERBOSE

if VERBOSE:
    
    print ("Operating System Platform: " + platform.system(), platform.release())
    print ("\n")

    print ("os.environ['PATH']: ", os.environ['PATH'])
    print ("sys.path: ", sys.path)
    print ("\n")

# %%
#https://api.jquery.com/ready/
HTML('''
<script>
    function scroll_to_top() {
        Jupyter.notebook.scroll_to_top();
    } 
    $( window ).on( "load", scroll_to_top() );
</script>
''')
# Out:
# <script>
#     function scroll_to_top() {
#         Jupyter.notebook.scroll_to_top();
#     }
#     $( window ).on( "load", scroll_to_top() );
# </script>

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
print ('\nDirectory tree of\n%s:\n' %Toolpath)
from utils.Tree import Tree
results_tree = Tree(Toolpath)
# results_tree.print_tree()
# Out:
# Directory tree of
# /Users/bkyanjo3/da_project/ICESEE-GHUB:

# %%
from _bootstrap._bootstrap import enable_icesee
enable_icesee()
# Out:
# [ICESEE bootstrap] external path enabled: /Users/bkyanjo3/da_project/ICESEE-GHUB/external
# [ICESEE bootstrap] ICESEE loaded from: /Users/bkyanjo3/da_project/ICESEE-GHUB/external/ICESEE/__init__.py
# PosixPath('/Users/bkyanjo3/da_project/ICESEE-GHUB/external')

# %%
# --- call the lorenz96 data assimilation example ---
import os, sys, traceback
try:
    os.system('mpirun -np 8 python3 -m ICESEE.applications.issm_model.examples.ISMIP_Choi.run_da_issm --Nens=40 --model_nprocs=2')
except Exception as e:
    print(f"Error occurred in __init__: {e}")
    tb_str = "".join(traceback.format_exception(*sys.exc_info()))
    print(f"Traceback details:\n{tb_str}") 
    os.system('python3 -m ICESEE.applications.issm_model.examples.ISMIP_Choi.kill_matlab_processes')
# Out:
# [ICESEE] Running default parallel mode
# Directory already exists: /Users/bkyanjo3/da_project/ISSM-matlab/examples/ISMIP_Choi
# [Rank 0] Copying with rsync: /Users/bkyanjo3/da_project/ICESEE-GHUB/external/ICESEE/applications/issm_model/examples/ISMIP_Choi/data/ISMIP.reference_simulation_0.mat to /Users/bkyanjo3/da_project/ISSM-matlab/examples/ISMIP_Choi/Models/ens_id_0/ISMIP.reference_simulation_0.mat
# [ICESEE ⇆ ISSM] stdout: < M A T L A B (R) >
# [ICESEE ⇆ ISSM] stdout: Copyright 1984-2024 The MathWorks, Inc.
# [ICESEE ⇆ ISSM] stdout: R2024b Update 6 (24.2.0.2923080) 64-bit (maca64)
# [ICESEE ⇆ ISSM] stdout: March 28, 2025
# [ICESEE ⇆ ISSM] stdout: To get started, type doc.
# [ICESEE ⇆ ISSM] stdout: For product information, visit www.mathworks.com.
# [ICESEE ⇆ ISSM] stdout: Server starting...
# [ICESEE ⇆ ISSM] stdout: Command file: /Users/bkyanjo3/da_project/ISSM-matlab/examples/ISMIP_Choi/cmdfile_0.txt
# ...

# %%
# call the icesee plotinting notebook
# Out:
# Found MATLAB process: MATLAB (PID: 8343)
# Skipped GUI MATLAB process (PID: 8343)
# Found MATLAB process: MATLABWebUI (GPU) (PID: 8484)
# Skipped GUI MATLAB process (PID: 8484)
# Found MATLAB process: MATLABWebUI (PID: 8487)
# Skipped GUI MATLAB process (PID: 8487)
# Found MATLAB process: MATLABWebUI (PID: 8488)
# Skipped GUI MATLAB process (PID: 8488)
# Found MATLAB process: MATLABWebUI (Renderer) (PID: 8490)
# Skipped GUI MATLAB process (PID: 8490)
# Found MATLAB process: MATLABWebUI (Renderer) (PID: 8491)
# Skipped GUI MATLAB process (PID: 8491)
# Found MATLAB process: MATLABWebUI (Renderer) (PID: 8535)
# Skipped GUI MATLAB process (PID: 8535)
# Found MATLAB process: MATLABWebUI (Renderer) (PID: 8536)
# Skipped GUI MATLAB process (PID: 8536)
# No non-GUI MATLAB processes found to terminate.
# 0
